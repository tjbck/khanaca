# %%
import requests
from bs4 import BeautifulSoup
import urllib.request
from pathlib import Path
import json

base_url = "https://www.khanacademy.org"

# %%
def html2script(soup):
    script = str(soup.find_all('script')[4])
    start = script.find('window["./javascript/app-shell-package/app-entry.js"] = ') + len('window["./javascript/app-shell-package/app-entry.js"] = ')
    end = script.find(';\n    </script>')
    script = script.replace('true', "True")
    script = script.replace('false', "False")
    script = script.replace('null', "None")
    return eval(script[start:end])

# %%
# Subject level
def get_modules(subject):
    r = requests.get(base_url + subject)
    soup = BeautifulSoup(r.text, 'html.parser')
    script = html2script(soup)
    return script['dataCache']['content-en'][list(script['dataCache']['content-en'].keys())[0]]['data']['tabs'][0]['modules'][1]['modules']

# for module in units:
#     print(module['url'])

# %%
# Unit level
# soup.find_all(attrs={"data-test-id":"unit-header"})
def get_units(unit):
    r = requests.get(base_url + unit)
    soup = BeautifulSoup(r.text, 'html.parser')
    script = html2script(soup)
    modules = script['dataCache']['content-en'][list(script['dataCache']['content-en'].keys())[0]]['data']['tabs'][0]['modules'][0]
    return modules['tutorials']

# %%
# Video download
def video_dl(item,folder_dir):
    urllib.request.urlretrieve(item['downloadUrls']['mp4'], f"./dl{folder_dir}/{item['slug']}.mp4") 
# "https://cdn.kastatic.org/ka-youtube-converted/Vi1JK6IYVt8.mp4/Vi1JK6IYVt8.mp4"

# %%
# Page level: Article

# for i in list(content.keys()):
#     print(i)
#     print(content[i])
#     print("\n\n\n")

def article_dl(item,folder_dir):
    r = requests.get(base_url+item['nodeUrl'])
    soup = BeautifulSoup(r.text, 'html.parser')
    script = html2script(soup)
    content = script['dataCache']['content-en'][list(script['dataCache']['content-en'].keys())[0]]['data']['tutorialPageData']['contentModel']
    data = eval(content['perseusContent'])
    with open(f"./dl{folder_dir}/{item['slug']}.json", 'w') as fp:
        json.dump(data, fp)

# %%
modules = get_modules("/science/health-and-medicine")

# %%
modules[12]
# Out:
# {'topicId': 'x0a1e9875',
#  'kind': 'SubjectPageTopicCard',
#  'description': 'The second tube formed during embryonic development is the one that will form our gastrointestinal tract. It starts at the mouth, includes the esophagus, stomach, accessory organs of the gut, and intestines, but sometimes things go wrong. Be gutsy and come learn about different diseases of the gastrointestinal tract with us!\n',
#  'links': [{'url': '/science/health-and-medicine/gastrointestinal-system-diseases#gastroenteritis',
#    'title': 'Gastroenteritis'},
#   {'url': '/science/health-and-medicine/gastrointestinal-system-diseases#inflammatory-bowel-disease',
#    'title': 'Inflammatory bowel disease'},
#   {'url': '/science/health-and-medicine/gastrointestinal-system-diseases#celiac-disease',
#    'title': 'Celiac disease'},
#   {'url': '/science/health-and-medicine/gastrointestinal-system-diseases#colon-diseases',
#    'title': 'Colon diseases'}],
#  'masteryPointsAvailable': 0,
#  'url': '/science/health-and-medicine/gastrointestinal-system-diseases',
#  'title': 'Gastrointestinal system diseases',
#  'masteryEnabled': False,
#  'numExercises': 0,
#  'subjectMasteryEnabled': False,
#  'rowIndex': 12,
#  'rowsTotal': 22,
#  'slug': 'gastrointestinal-system-diseases',
#  'icon': 'https://cdn.kastatic.org/genfiles/topic-icons/icons/gastrointestinal_system_diseases.png-ad81f3-128c.png'}

# %%
units = get_units("/science/health-and-medicine/human-anatomy-and-physiology")

# %%
folder_dir = units[0]['url'].replace('#',"/")
# Out:
# '/science/health-and-medicine/human-anatomy-and-physiology/heart-introduction'

# %%
units[0]['contentItems'][1]
# Out:
# {'nodeUrl': '/science/health-and-medicine/human-anatomy-and-physiology/heart-introduction/v/flow-through-the-heart',
#  'kind': 'Video',
#  'translatedYoutubeLang': 'en',
#  'description': 'Learn how blood flows through the heart, and understand the difference between systemic and pulmonary blood flow. Rishi is a pediatric infectious disease physician and works at Khan Academy.',
#  'title': 'Flow through the heart',
#  'contentId': '1081230475',
#  'downloadUrls': {'mp4': 'https://cdn.kastatic.org/ka-youtube-converted/7XaftdE_h60.mp4/7XaftdE_h60.mp4',
#   'png': 'https://cdn.kastatic.org/ka-youtube-converted/7XaftdE_h60.mp4/7XaftdE_h60.png',
#   'm3u8': 'https://cdn.kastatic.org/ka-youtube-converted/7XaftdE_h60.m3u8/7XaftdE_h60.m3u8'},
#  'translatedYoutubeId': '7XaftdE_h60',
#  'sponsored': False,
#  'youtubeId': '7XaftdE_h60',
#  'bigBingoLinkConversions': ['topic_page_click_video'],
#  'duration': 471,
#  'thumbnailUrl': 'https://cdn.kastatic.org/googleusercontent/oZ6EhbCXlLF8nqwCrKPR1Z4ftBWhk54hdKa9fGwBCm5IRu2rqouGgpU9MTWst9rAQJyZW_7WHiSxn0aIX6dVYHZr',
#  'slug': 'flow-through-the-heart',
#  'progressKey': 'v1081230475'}

# %%
for module in modules:
    print("NEW MODULE")
    print(module['title'])
    units = get_units(module['url'])
    for unit in units:
        folder_dir = unit['url'].replace('#',"/")
        Path("./dl/"+folder_dir).mkdir(parents=True, exist_ok=True)
        print("NEW UNIT")
        print(unit['title'])
        for i in unit['contentItems']:
            if(i['kind'] == 'Video'):
                print("Video")
                video_dl(i,folder_dir)
            if(i['kind'] == 'Article'):
                print("Article")
                article_dl(i,folder_dir)
        print('')
    print("\n")
# Out:
# NEW MODULE
# Human anatomy and physiology
# NEW UNIT
# Circulatory system introduction
# Video
# Video
# Video
# Article
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Respiratory system introduction
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Urinary system introduction
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Hematologic system introduction
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Immunologic system introduction
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Gastrointestinal system introduction
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Nervous system introduction
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Muscular system introduction
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Skeletal system introduction
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Endocrine system introduction
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Integumentary system introduction
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Lymphatic system introduction
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Reproductive system introduction
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Pregnancy and pregnancy complications
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
#
#
# NEW MODULE
# Advanced circulatory system physiology
# NEW UNIT
# Circulatory system introduction
# Video
# Video
# Video
# Article
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Blood pressure
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Blood pressure control
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Fetal circulation
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Blood vessels
# Video
# Video
# Video
#
# NEW UNIT
# Arterial stiffness
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Heart muscle contraction
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Heart depolarization
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Nerve regulation of the heart
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Preload and afterload
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Pressure volume loops
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Changing the PV loop
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
#
#
# NEW MODULE
# Circulatory system diseases
# NEW UNIT
# Coronary artery disease
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Atherosclerosis, arteriosclerosis, and arteriolosclerosis
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Stroke
# Article
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Hypertension
# Article
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Heart failure
# Article
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Aortic dissection and aneurysm
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Myocarditis and pericarditis
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Cardiomyopathy
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Cardiac dysrhythmias and tachycardias
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Heart valve diseases
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Acyanotic heart diseases
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Cyanotic heart diseases
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Shock
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Vasculitis
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Hypertension
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
#
#
# NEW MODULE
# Advanced respiratory system physiology
# NEW UNIT
# Respiratory system introduction
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Gas exchange
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Breathing control
# Video
# Video
# Video
# Video
#
#
#
# NEW MODULE
# Respiratory system diseases
# NEW UNIT
# Introduction to pulmonary diseases
# Video
# Video
# Article
# Video
#
# NEW UNIT
# Asthma
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Emphysema (COPD)
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Chronic Bronchitis (COPD)
# Video
# Video
# Video
#
# NEW UNIT
# Cystic fibrosis
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Occupational lung diseases
# Video
# Video
#
# NEW UNIT
# Pulmonary hypertension
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Pneumonia
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Pleural Effusion
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Lung cancer
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Nose, sinus, and upper respiratory conditions
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Throat conditions
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Laryngeal conditions
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Bronchiolitis
# Video
# Video
# Video
# Video
#
#
#
# NEW MODULE
# Advanced hematologic system physiology
# NEW UNIT
# Hematologic system introduction
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Bleeding and impaired hemostasis
# Video
# Video
# Video
# Video
#
#
#
# NEW MODULE
# Hematologic system diseases
# NEW UNIT
# Anemia
# Article
# Video
# Video
# Video
#
# NEW UNIT
# Leukemia
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Iron deficiency anemia and anemia of chronic disease
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Plasma cell dyscrasias
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Myeloproliferative disorders
# Video
# Video
# Video
# Video
# Video
#
#
#
# NEW MODULE
# Advanced endocrine system physiology
# NEW UNIT
# Endocrine system introduction
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Biological basis of behavior: Endocrine system
# Video
# Video
# Video
# Video
#
#
#
# NEW MODULE
# Endocrine system diseases
# NEW UNIT
# Diabetes
# Article
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
#
#
# NEW MODULE
# Advanced nervous system physiology
# NEW UNIT
# Nervous system introduction
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Neural cells and neurotransmitters
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Neuron membrane potentials
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Sensory perception
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Sight (vision)
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Sound (Audition)
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Somatosensation
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Taste (gustation) and smell (olfaction)
# Video
# Video
# Video
#
#
#
# NEW MODULE
# Nervous system diseases
# NEW UNIT
# Parkinson's disease
# Article
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Multiple sclerosis
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
#
#
# NEW MODULE
# Advanced gastrointestinal physiology
# NEW UNIT
# Gastrointestinal system introduction
# Video
#
#
#
# NEW MODULE
# Gastrointestinal system diseases
# NEW UNIT
# Gastroenteritis
# Article
# Video
# Video
# Video
# Video
# Video
# Video
# Video
# Video
#
# NEW UNIT
# Inflammatory bowel disease
# Video
# Video
# Video
# ---------------------------------------------------------------------------
# ConnectionAbortedError                    Traceback (most recent call last)
# <ipython-input-77-5253633d4134> in <module>()
#      11             if(i['kind'] == 'Video'):
#      12                 print("Video")
# ---> 13                 video_dl(i,folder_dir)
#      14             if(i['kind'] == 'Article'):
#      15                 print("Article")
#
# <ipython-input-76-54c8b4dc9a36> in video_dl(item, folder_dir)
#       1 # Video download
#       2 def video_dl(item,folder_dir):
# ----> 3     urllib.request.urlretrieve(item['downloadUrls']['mp4'], f"./dl{folder_dir}/{item['slug']}.mp4")
#       4 # "https://cdn.kastatic.org/ka-youtube-converted/Vi1JK6IYVt8.mp4/Vi1JK6IYVt8.mp4"
#
# c:\program files\python36\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     275
#     276             while True:
# --> 277                 block = fp.read(bs)
#     278                 if not block:
#     279                     break
#
# c:\program files\python36\lib\http\client.py in read(self, amt)
#     447             # Amount is given, implement using readinto
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#     451         else:
#
# c:\program files\python36\lib\http\client.py in readinto(self, b)
#     491         # connection, and the user is reading more bytes than will be provided
#     492         # (for example, reading in 1k chunks)
# --> 493         n = self.fp.readinto(b)
#     494         if not n and b:
#     495             # Ideally, we would raise IncompleteRead if the content-length
#
# c:\program files\python36\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# c:\program files\python36\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1007                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1008                   self.__class__)
# -> 1009             return self.read(nbytes, buffer)
#    1010         else:
#    1011             return socket.recv_into(self, buffer, nbytes, flags)
#
# c:\program files\python36\lib\ssl.py in read(self, len, buffer)
#     869             raise ValueError("Read on closed or unwrapped SSL socket.")
#     870         try:
# --> 871             return self._sslobj.read(len, buffer)
#     872         except SSLError as x:
#     873             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# c:\program files\python36\lib\ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# ConnectionAbortedError: [WinError 10053] An established connection was aborted by the software in your host machine

# %%
# TODO: QUIZ 
r = requests.get(base_url+"/science/health-and-medicine/human-anatomy-and-physiology/heart-introduction/e/heart-quiz")
soup = BeautifulSoup(r.text, 'html.parser')
script = html2script(soup)
